# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
tide_2010_atlantic = pd.read_csv('./data/Atlantic_city_data/tide_levels/tide_2010.csv')
tide_2011_atlantic = pd.read_csv('./data/Atlantic_city_data/tide_levels/tide_2011.csv')
tide_2012_atlantic = pd.read_csv('./data/Atlantic_city_data/tide_levels/tide_2012.csv')
tide_2013_atlantic = pd.read_csv('./data/Atlantic_city_data/tide_levels/tide_2013.csv')
tide_2014_atlantic = pd.read_csv('./data/Atlantic_city_data/tide_levels/tide_2014.csv')
tide_2015_atlantic = pd.read_csv('./data/Atlantic_city_data/tide_levels/tide_2015.csv')
tide_2010_boston = pd.read_csv('./data/Boston/tide_levels/tide_2010.csv')
tide_2011_boston = pd.read_csv('./data/Boston/tide_levels/tide_2011.csv')
tide_2012_boston = pd.read_csv('./data/Boston/tide_levels/tide_2012.csv')
tide_2013_boston = pd.read_csv('./data/Boston/tide_levels/tide_2013.csv')
tide_2014_boston = pd.read_csv('./data/Boston/tide_levels/tide_2014.csv')
tide_2015_boston = pd.read_csv('./data/Boston/tide_levels/tide_2015.csv')
tide_2010_bridgeport = pd.read_csv('./data/bridgeport_data/tide_levels/tide_2010.csv')
tide_2011_bridgeport = pd.read_csv('./data/bridgeport_data/tide_levels/tide_2011.csv')
tide_2012_bridgeport = pd.read_csv('./data/bridgeport_data/tide_levels/tide_2012.csv')
tide_2013_bridgeport = pd.read_csv('./data/bridgeport_data/tide_levels/tide_2013.csv')
tide_2014_bridgeport = pd.read_csv('./data/bridgeport_data/tide_levels/tide_2014.csv')
tide_2015_bridgeport = pd.read_csv('./data/bridgeport_data/tide_levels/tide_2015.csv')
tide_2010_new_haven = pd.read_csv('./data/new_haven_data/tide_levels/tide_2010.csv')
tide_2011_new_haven = pd.read_csv('./data/new_haven_data/tide_levels/tide_2011.csv')
tide_2012_new_haven = pd.read_csv('./data/new_haven_data/tide_levels/tide_2012.csv')
tide_2013_new_haven = pd.read_csv('./data/new_haven_data/tide_levels/tide_2013.csv')
tide_2014_new_haven = pd.read_csv('./data/new_haven_data/tide_levels/tide_2014.csv')
tide_2015_new_haven = pd.read_csv('./data/new_haven_data/tide_levels/tide_2015.csv')
tide_2010_new_london = pd.read_csv('./data/new_london_data/tide_levels/tide_2010.csv')
tide_2011_new_london = pd.read_csv('./data/new_london_data/tide_levels/tide_2011.csv')
tide_2012_new_london = pd.read_csv('./data/new_london_data/tide_levels/tide_2012.csv')
tide_2013_new_london = pd.read_csv('./data/new_london_data/tide_levels/tide_2013.csv')
tide_2014_new_london = pd.read_csv('./data/new_london_data/tide_levels/tide_2014.csv')
tide_2015_new_london = pd.read_csv('./data/new_london_data/tide_levels/tide_2015.csv')
tide_2010_newport = pd.read_csv('./data/newport/tide_levels/tide_2010.csv')
tide_2011_newport = pd.read_csv('./data/newport/tide_levels/tide_2011.csv')
tide_2012_newport = pd.read_csv('./data/newport/tide_levels/tide_2012.csv')
tide_2013_newport = pd.read_csv('./data/newport/tide_levels/tide_2013.csv')
tide_2014_newport = pd.read_csv('./data/newport/tide_levels/tide_2014.csv')
tide_2015_newport = pd.read_csv('./data/newport/tide_levels/tide_2015.csv')
tide_2010_baltimore = pd.read_csv('./data/baltimore_data/tide/tide_2010.csv')
tide_2011_baltimore = pd.read_csv('./data/baltimore_data/tide/tide_2011.csv')
tide_2012_baltimore = pd.read_csv('./data/baltimore_data/tide/tide_2012.csv')
tide_2013_baltimore = pd.read_csv('./data/baltimore_data/tide/tide_2013.csv')
tide_2014_baltimore = pd.read_csv('./data/baltimore_data/tide/tide_2014.csv')
tide_2015_baltimore = pd.read_csv('./data/baltimore_data/tide/tide_2015.csv')
tide_2010_ocean_city = pd.read_csv('./data/ocean_city/tide_levels/tide_2010.csv')
tide_2011_ocean_city = pd.read_csv('./data/ocean_city/tide_levels/tide_2011.csv')
tide_2012_ocean_city = pd.read_csv('./data/ocean_city/tide_levels/tide_2012.csv')
tide_2013_ocean_city = pd.read_csv('./data/ocean_city/tide_levels/tide_2013.csv')
tide_2014_ocean_city = pd.read_csv('./data/ocean_city/tide_levels/tide_2014.csv')
tide_2015_ocean_city = pd.read_csv('./data/ocean_city/tide_levels/tide_2015.csv')
tide_2010_portland = pd.read_csv('./data/portland/tide_levels/tide_2010.csv')
tide_2011_portland = pd.read_csv('./data/portland/tide_levels/tide_2011.csv')
tide_2012_portland = pd.read_csv('./data/portland/tide_levels/tide_2012.csv')
tide_2013_portland = pd.read_csv('./data/portland/tide_levels/tide_2013.csv')
tide_2014_portland = pd.read_csv('./data/portland/tide_levels/tide_2014.csv')
tide_2015_portland = pd.read_csv('./data/portland/tide_levels/tide_2015.csv')
tide_2010_providence = pd.read_csv('./data/providence/tide_levels/tide_2010.csv')
tide_2011_providence = pd.read_csv('./data/providence/tide_levels/tide_2011.csv')
tide_2012_providence = pd.read_csv('./data/providence/tide_levels/tide_2012.csv')
tide_2013_providence = pd.read_csv('./data/providence/tide_levels/tide_2013.csv')
tide_2014_providence = pd.read_csv('./data/providence/tide_levels/tide_2014.csv')
tide_2015_providence = pd.read_csv('./data/providence/tide_levels/tide_2015.csv')

# %%
def clean_tide_max(df):
    df = df.drop(columns= ['Predicted (ft)', 'Preliminary (ft)'], axis=1)
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.set_index('Date')
    #df.index = pd.to_datetime(df.index, format='%Y-%m')
    df = df[df['Verified (ft)'] != '-']
    df['Verified (ft) Max'] = pd.to_numeric(df['Verified (ft)'])
    df = df.resample('D').max()
    return df

# %%
def clean_tide_mean(df):
    df = df.drop(columns= ['Predicted (ft)', 'Preliminary (ft)'], axis=1)
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.set_index('Date')
    #df.index = pd.to_datetime(df.index, format='%Y-%m')
    df = df[df['Verified (ft)'] != '-']
    df['Verified (ft) Max'] = pd.to_numeric(df['Verified (ft)'])
    df = df.resample('D').mean()
    return df

# %%
tide_2010_atlantic_max = clean_tide_max(tide_2010_atlantic)
tide_2011_atlantic_max = clean_tide_max(tide_2011_atlantic)
tide_2012_atlantic_max = clean_tide_max(tide_2012_atlantic)
tide_2013_atlantic_max = clean_tide_max(tide_2013_atlantic)
tide_2014_atlantic_max = clean_tide_max(tide_2014_atlantic)
tide_2015_atlantic_max = clean_tide_max(tide_2015_atlantic)
tide_2010_boston_max = clean_tide_max(tide_2010_boston)
tide_2011_boston_max = clean_tide_max(tide_2011_boston)
tide_2012_boston_max = clean_tide_max(tide_2012_boston)
tide_2013_boston_max = clean_tide_max(tide_2013_boston)
tide_2014_boston_max = clean_tide_max(tide_2014_boston)
tide_2015_boston_max = clean_tide_max(tide_2015_boston)
tide_2010_bridgeport_max = clean_tide_max(tide_2010_bridgeport)
tide_2011_bridgeport_max = clean_tide_max(tide_2011_bridgeport)
tide_2012_bridgeport_max = clean_tide_max(tide_2012_bridgeport)
tide_2013_bridgeport_max = clean_tide_max(tide_2013_bridgeport)
tide_2014_bridgeport_max = clean_tide_max(tide_2014_bridgeport)
tide_2015_bridgeport_max = clean_tide_max(tide_2015_bridgeport)
tide_2010_new_haven_max = clean_tide_max(tide_2010_new_haven)
tide_2011_new_haven_max = clean_tide_max(tide_2011_new_haven)
tide_2012_new_haven_max = clean_tide_max(tide_2012_new_haven)
tide_2013_new_haven_max = clean_tide_max(tide_2013_new_haven)
tide_2014_new_haven_max = clean_tide_max(tide_2014_new_haven)
tide_2015_new_haven_max = clean_tide_max(tide_2015_new_haven)
tide_2010_new_london_max = clean_tide_max(tide_2010_new_london)
tide_2011_new_london_max = clean_tide_max(tide_2011_new_london)
tide_2012_new_london_max = clean_tide_max(tide_2012_new_london)
tide_2013_new_london_max = clean_tide_max(tide_2013_new_london)
tide_2014_new_london_max = clean_tide_max(tide_2014_new_london)
tide_2015_new_london_max = clean_tide_max(tide_2015_new_london)
tide_2010_newport_max = clean_tide_max(tide_2010_newport)
tide_2011_newport_max = clean_tide_max(tide_2011_newport)
tide_2012_newport_max = clean_tide_max(tide_2012_newport)
tide_2013_newport_max = clean_tide_max(tide_2013_newport)
tide_2014_newport_max = clean_tide_max(tide_2014_newport)
tide_2015_newport_max = clean_tide_max(tide_2015_newport)
tide_2010_baltimore_max = clean_tide_max(tide_2010_baltimore)
tide_2011_baltimore_max = clean_tide_max(tide_2011_baltimore)
tide_2012_baltimore_max = clean_tide_max(tide_2012_baltimore)
tide_2013_baltimore_max = clean_tide_max(tide_2013_baltimore)
tide_2014_baltimore_max = clean_tide_max(tide_2014_baltimore)
tide_2015_baltimore_max = clean_tide_max(tide_2015_baltimore)
tide_2010_ocean_city_max = clean_tide_max(tide_2010_ocean_city)
tide_2011_ocean_city_max = clean_tide_max(tide_2011_ocean_city)
tide_2012_ocean_city_max = clean_tide_max(tide_2012_ocean_city)
tide_2013_ocean_city_max = clean_tide_max(tide_2013_ocean_city)
tide_2014_ocean_city_max = clean_tide_max(tide_2014_ocean_city)
tide_2015_ocean_city_max = clean_tide_max(tide_2015_ocean_city)
tide_2010_portland_max = clean_tide_max(tide_2010_portland)
tide_2011_portland_max = clean_tide_max(tide_2011_portland)
tide_2012_portland_max = clean_tide_max(tide_2012_portland)
tide_2013_portland_max = clean_tide_max(tide_2013_portland)
tide_2014_portland_max = clean_tide_max(tide_2014_portland)
tide_2015_portland_max = clean_tide_max(tide_2015_portland)
tide_2010_providence_max = clean_tide_max(tide_2010_providence)
tide_2011_providence_max = clean_tide_max(tide_2011_providence)
tide_2012_providence_max = clean_tide_max(tide_2012_providence)
tide_2013_providence_max = clean_tide_max(tide_2013_providence)
tide_2014_providence_max = clean_tide_max(tide_2014_providence)
tide_2015_providence_max = clean_tide_max(tide_2015_providence)

# %%
tide_2010_atlantic_mean = clean_tide_mean(tide_2010_atlantic)
tide_2011_atlantic_mean = clean_tide_mean(tide_2011_atlantic)
tide_2012_atlantic_mean = clean_tide_mean(tide_2012_atlantic)
tide_2013_atlantic_mean = clean_tide_mean(tide_2013_atlantic)
tide_2014_atlantic_mean = clean_tide_mean(tide_2014_atlantic)
tide_2015_atlantic_mean = clean_tide_mean(tide_2015_atlantic)
tide_2010_boston_mean = clean_tide_mean(tide_2010_boston)
tide_2011_boston_mean = clean_tide_mean(tide_2011_boston)
tide_2012_boston_mean = clean_tide_mean(tide_2012_boston)
tide_2013_boston_mean = clean_tide_mean(tide_2013_boston)
tide_2014_boston_mean = clean_tide_mean(tide_2014_boston)
tide_2015_boston_mean = clean_tide_mean(tide_2015_boston)
tide_2010_bridgeport_mean = clean_tide_mean(tide_2010_bridgeport)
tide_2011_bridgeport_mean = clean_tide_mean(tide_2011_bridgeport)
tide_2012_bridgeport_mean = clean_tide_mean(tide_2012_bridgeport)
tide_2013_bridgeport_mean = clean_tide_mean(tide_2013_bridgeport)
tide_2014_bridgeport_mean = clean_tide_mean(tide_2014_bridgeport)
tide_2015_bridgeport_mean = clean_tide_mean(tide_2015_bridgeport)
tide_2010_new_haven_mean = clean_tide_mean(tide_2010_new_haven)
tide_2011_new_haven_mean = clean_tide_mean(tide_2011_new_haven)
tide_2012_new_haven_mean = clean_tide_mean(tide_2012_new_haven)
tide_2013_new_haven_mean = clean_tide_mean(tide_2013_new_haven)
tide_2014_new_haven_mean = clean_tide_mean(tide_2014_new_haven)
tide_2015_new_haven_mean = clean_tide_mean(tide_2015_new_haven)
tide_2010_new_london_mean = clean_tide_mean(tide_2010_new_london)
tide_2011_new_london_mean = clean_tide_mean(tide_2011_new_london)
tide_2012_new_london_mean = clean_tide_mean(tide_2012_new_london)
tide_2013_new_london_mean = clean_tide_mean(tide_2013_new_london)
tide_2014_new_london_mean = clean_tide_mean(tide_2014_new_london)
tide_2015_new_london_mean = clean_tide_mean(tide_2015_new_london)
tide_2010_newport_mean = clean_tide_mean(tide_2010_newport)
tide_2011_newport_mean = clean_tide_mean(tide_2011_newport)
tide_2012_newport_mean = clean_tide_mean(tide_2012_newport)
tide_2013_newport_mean = clean_tide_mean(tide_2013_newport)
tide_2014_newport_mean = clean_tide_mean(tide_2014_newport)
tide_2015_newport_mean = clean_tide_mean(tide_2015_newport)
tide_2010_baltimore_mean = clean_tide_mean(tide_2010_baltimore)
tide_2011_baltimore_mean = clean_tide_mean(tide_2011_baltimore)
tide_2012_baltimore_mean = clean_tide_mean(tide_2012_baltimore)
tide_2013_baltimore_mean = clean_tide_mean(tide_2013_baltimore)
tide_2014_baltimore_mean = clean_tide_mean(tide_2014_baltimore)
tide_2015_baltimore_mean = clean_tide_mean(tide_2015_baltimore)
tide_2010_ocean_city_mean = clean_tide_mean(tide_2010_ocean_city)
tide_2011_ocean_city_mean = clean_tide_mean(tide_2011_ocean_city)
tide_2012_ocean_city_mean = clean_tide_mean(tide_2012_ocean_city)
tide_2013_ocean_city_mean = clean_tide_mean(tide_2013_ocean_city)
tide_2014_ocean_city_mean = clean_tide_mean(tide_2014_ocean_city)
tide_2015_ocean_city_mean = clean_tide_mean(tide_2015_ocean_city)
tide_2010_portland_mean = clean_tide_mean(tide_2010_portland)
tide_2011_portland_mean = clean_tide_mean(tide_2011_portland)
tide_2012_portland_mean = clean_tide_mean(tide_2012_portland)
tide_2013_portland_mean = clean_tide_mean(tide_2013_portland)
tide_2014_portland_mean = clean_tide_mean(tide_2014_portland)
tide_2015_portland_mean = clean_tide_mean(tide_2015_portland)
tide_2010_providence_mean = clean_tide_mean(tide_2010_providence)
tide_2011_providence_mean = clean_tide_mean(tide_2011_providence)
tide_2012_providence_mean = clean_tide_mean(tide_2012_providence)
tide_2013_providence_mean = clean_tide_mean(tide_2013_providence)
tide_2014_providence_mean = clean_tide_mean(tide_2014_providence)
tide_2015_providence_mean = clean_tide_mean(tide_2015_providence)

# %%
atlantic_tide_max = pd.concat([tide_2010_atlantic_max, tide_2011_atlantic_max, tide_2012_atlantic_max, tide_2013_atlantic_max, tide_2014_atlantic_max, tide_2015_atlantic_max])
boston_tide_max = pd.concat([tide_2010_boston_max, tide_2011_boston_max, tide_2012_boston_max, tide_2013_boston_max, tide_2014_boston_max, tide_2015_boston_max])
bridgeport_tide_max = pd.concat([tide_2010_bridgeport_max, tide_2011_bridgeport_max, tide_2012_bridgeport_max, tide_2013_bridgeport_max, tide_2014_bridgeport_max, tide_2015_bridgeport_max])
new_haven_tide_max = pd.concat([tide_2010_new_haven_max, tide_2011_new_haven_max, tide_2012_new_haven_max, tide_2013_new_haven_max, tide_2014_new_haven_max, tide_2015_new_haven_max])
new_london_tide_max = pd.concat([tide_2010_new_london_max, tide_2011_new_london_max, tide_2012_new_london_max, tide_2013_new_london_max, tide_2014_new_london_max, tide_2015_new_london_max])
newport_tide_max = pd.concat([tide_2010_newport_max, tide_2011_newport_max, tide_2012_newport_max, tide_2013_newport_max, tide_2014_newport_max, tide_2015_newport_max])
baltimore_tide_max = pd.concat([tide_2010_baltimore_max, tide_2011_baltimore_max, tide_2012_baltimore_max, tide_2013_baltimore_max, tide_2014_baltimore_max, tide_2015_baltimore_max])
ocean_city_tide_max = pd.concat([tide_2010_baltimore_max, tide_2011_baltimore_max, tide_2012_baltimore_max, tide_2013_baltimore_max, tide_2014_baltimore_max, tide_2015_baltimore_max])
portland_tide_max = pd.concat([tide_2010_portland_max, tide_2011_portland_max, tide_2012_portland_max, tide_2013_portland_max, tide_2014_portland_max, tide_2015_portland_max])
providence_tide_max = pd.concat([tide_2010_providence_max, tide_2011_providence_max, tide_2012_providence_max, tide_2013_providence_max, tide_2014_providence_max, tide_2015_providence_max])

# %%
atlantic_tide_mean = pd.concat([tide_2010_atlantic_mean, tide_2011_atlantic_mean, tide_2012_atlantic_mean, tide_2013_atlantic_mean, tide_2014_atlantic_mean, tide_2015_atlantic_mean])
boston_tide_mean = pd.concat([tide_2010_boston_mean, tide_2011_boston_mean, tide_2012_boston_mean, tide_2013_boston_mean, tide_2014_boston_mean, tide_2015_boston_mean])
bridgeport_tide_mean = pd.concat([tide_2010_bridgeport_mean, tide_2011_bridgeport_mean, tide_2012_bridgeport_mean, tide_2013_bridgeport_mean, tide_2014_bridgeport_mean, tide_2015_bridgeport_mean])
new_haven_tide_mean = pd.concat([tide_2010_new_haven_mean, tide_2011_new_haven_mean, tide_2012_new_haven_mean, tide_2013_new_haven_mean, tide_2014_new_haven_mean, tide_2015_new_haven_mean])
new_london_tide_mean = pd.concat([tide_2010_new_london_mean, tide_2011_new_london_mean, tide_2012_new_london_mean, tide_2013_new_london_mean, tide_2014_new_london_mean, tide_2015_new_london_mean])
newport_tide_mean = pd.concat([tide_2010_newport_mean, tide_2011_newport_mean, tide_2012_newport_mean, tide_2013_newport_mean, tide_2014_newport_mean, tide_2015_newport_mean])
baltimore_tide_mean = pd.concat([tide_2010_baltimore_mean, tide_2011_baltimore_mean, tide_2012_baltimore_mean, tide_2013_baltimore_mean, tide_2014_baltimore_mean, tide_2015_baltimore_mean])
ocean_city_tide_mean = pd.concat([tide_2010_baltimore_mean, tide_2011_baltimore_mean, tide_2012_baltimore_mean, tide_2013_baltimore_mean, tide_2014_baltimore_mean, tide_2015_baltimore_mean])
portland_tide_mean = pd.concat([tide_2010_portland_mean, tide_2011_portland_mean, tide_2012_portland_mean, tide_2013_portland_mean, tide_2014_portland_mean, tide_2015_portland_mean])
providence_tide_mean = pd.concat([tide_2010_providence_mean, tide_2011_providence_mean, tide_2012_providence_mean, tide_2013_providence_mean, tide_2014_providence_mean, tide_2015_providence_mean])

# %%
baro_2010_atlantic = pd.read_csv('./data/Atlantic_city_data/baro_pressure/baro_2010.csv')
baro_2011_atlantic = pd.read_csv('./data/Atlantic_city_data/baro_pressure/baro_2011.csv')
baro_2012_atlantic = pd.read_csv('./data/Atlantic_city_data/baro_pressure/baro_2012.csv')
baro_2013_atlantic = pd.read_csv('./data/Atlantic_city_data/baro_pressure/baro_2013.csv')
baro_2014_atlantic = pd.read_csv('./data/Atlantic_city_data/baro_pressure/baro_2014.csv')
baro_2015_atlantic = pd.read_csv('./data/Atlantic_city_data/baro_pressure/baro_2015.csv')
baro_2010_boston = pd.read_csv('./data/Boston/baro_pressure/baro_2010.csv')
baro_2011_boston = pd.read_csv('./data/Boston/baro_pressure/baro_2011.csv')
baro_2012_boston = pd.read_csv('./data/Boston/baro_pressure/baro_2012.csv')
baro_2013_boston = pd.read_csv('./data/Boston/baro_pressure/baro_2013.csv')
baro_2014_boston = pd.read_csv('./data/Boston/baro_pressure/baro_2014.csv')
baro_2015_boston = pd.read_csv('./data/Boston/baro_pressure/baro_2015.csv')
baro_2010_bridgeport = pd.read_csv('./data/bridgeport_data/baro_pressure/baro_2010.csv')
baro_2011_bridgeport = pd.read_csv('./data/bridgeport_data/baro_pressure/baro_2011.csv')
baro_2012_bridgeport = pd.read_csv('./data/bridgeport_data/baro_pressure/baro_2012.csv')
baro_2013_bridgeport = pd.read_csv('./data/bridgeport_data/baro_pressure/baro_2013.csv')
baro_2014_bridgeport = pd.read_csv('./data/bridgeport_data/baro_pressure/baro_2014.csv')
baro_2015_bridgeport = pd.read_csv('./data/bridgeport_data/baro_pressure/baro_2015.csv')
baro_2010_new_haven = pd.read_csv('./data/new_haven_data/baro_pressure/baro_2010.csv')
baro_2011_new_haven = pd.read_csv('./data/new_haven_data/baro_pressure/baro_2011.csv')
baro_2012_new_haven = pd.read_csv('./data/new_haven_data/baro_pressure/baro_2012.csv')
baro_2013_new_haven = pd.read_csv('./data/new_haven_data/baro_pressure/baro_2013.csv')
baro_2014_new_haven = pd.read_csv('./data/new_haven_data/baro_pressure/baro_2014.csv')
baro_2015_new_haven = pd.read_csv('./data/new_haven_data/baro_pressure/baro_2015.csv')
baro_2010_new_london = pd.read_csv('./data/new_london_data/baro_pressure/baro_2010.csv')
baro_2011_new_london = pd.read_csv('./data/new_london_data/baro_pressure/baro_2011.csv')
baro_2012_new_london = pd.read_csv('./data/new_london_data/baro_pressure/baro_2012.csv')
baro_2013_new_london = pd.read_csv('./data/new_london_data/baro_pressure/baro_2013.csv')
baro_2014_new_london = pd.read_csv('./data/new_london_data/baro_pressure/baro_2014.csv')
baro_2015_new_london = pd.read_csv('./data/new_london_data/baro_pressure/baro_2015.csv')
baro_2010_newport = pd.read_csv('./data/newport/baro_pressure/baro_2010.csv')
baro_2011_newport = pd.read_csv('./data/newport/baro_pressure/baro_2011.csv')
baro_2012_newport = pd.read_csv('./data/newport/baro_pressure/baro_2012.csv')
baro_2013_newport = pd.read_csv('./data/newport/baro_pressure/baro_2013.csv')
baro_2014_newport = pd.read_csv('./data/newport/baro_pressure/baro_2014.csv')
baro_2015_newport = pd.read_csv('./data/newport/baro_pressure/baro_2015.csv')
baro_2010_baltimore = pd.read_csv('./data/baltimore_data/baro_pressure/baro_2010.csv')
baro_2011_baltimore = pd.read_csv('./data/baltimore_data/baro_pressure/baro_2011.csv')
baro_2012_baltimore = pd.read_csv('./data/baltimore_data/baro_pressure/baro_2012.csv')
baro_2013_baltimore = pd.read_csv('./data/baltimore_data/baro_pressure/baro_2013.csv')
baro_2014_baltimore = pd.read_csv('./data/baltimore_data/baro_pressure/baro_2014.csv')
baro_2015_baltimore = pd.read_csv('./data/baltimore_data/baro_pressure/baro_2015.csv')
baro_2010_ocean_city = pd.read_csv('./data/ocean_city/baro_pressure/baro_2010.csv')
baro_2011_ocean_city = pd.read_csv('./data/ocean_city/baro_pressure/baro_2011.csv')
baro_2012_ocean_city = pd.read_csv('./data/ocean_city/baro_pressure/baro_2012.csv')
baro_2013_ocean_city = pd.read_csv('./data/ocean_city/baro_pressure/baro_2013.csv')
baro_2014_ocean_city = pd.read_csv('./data/ocean_city/baro_pressure/baro_2014.csv')
baro_2015_ocean_city = pd.read_csv('./data/ocean_city/baro_pressure/baro_2015.csv')
baro_2010_portland = pd.read_csv('./data/portland/baro_pressure/baro_2010.csv')
baro_2011_portland = pd.read_csv('./data/portland/baro_pressure/baro_2011.csv')
baro_2012_portland = pd.read_csv('./data/portland/baro_pressure/baro_2012.csv')
baro_2013_portland = pd.read_csv('./data/portland/baro_pressure/baro_2013.csv')
baro_2014_portland = pd.read_csv('./data/portland/baro_pressure/baro_2014.csv')
baro_2015_portland = pd.read_csv('./data/portland/baro_pressure/baro_2015.csv')
baro_2010_providence = pd.read_csv('./data/providence/baro_pressure/baro_2010.csv')
baro_2011_providence = pd.read_csv('./data/providence/baro_pressure/baro_2011.csv')
baro_2012_providence = pd.read_csv('./data/providence/baro_pressure/baro_2012.csv')
baro_2013_providence = pd.read_csv('./data/providence/baro_pressure/baro_2013.csv')
baro_2014_providence = pd.read_csv('./data/providence/baro_pressure/baro_2014.csv')
baro_2015_providence = pd.read_csv('./data/providence/baro_pressure/baro_2015.csv')

# %%
def clean_baro_max(df):
    #df['DATE TIME'] = df['DATE TIME']#.map(lambda x: x[:10])
    df = df[['DATE TIME', ' BARO']]
    df.rename(columns={'DATE TIME': 'Date', ' BARO': 'baro'}, inplace=True)
    #df['Date'] = df['Date'].map(lambda x: x[:7])
    df.dropna(inplace=True)
    df = df.set_index('Date')
    df.index = pd.to_datetime(df.index)#, format='%Y-%m')
    df['baro'] = pd.to_numeric(df['baro'])
    df = df.resample('D').max()
    return df

# %%
def clean_baro_mean(df):
    #df['DATE TIME'] = df['DATE TIME']#.map(lambda x: x[:10])
    df = df[['DATE TIME', ' BARO']]
    df.rename(columns={'DATE TIME': 'Date', ' BARO': 'baro'}, inplace=True)
    #df['Date'] = df['Date'].map(lambda x: x[:7])
    df.dropna(inplace=True)
    df = df.set_index('Date')
    df.index = pd.to_datetime(df.index)#, format='%Y-%m')
    df['baro'] = pd.to_numeric(df['baro'])
    df = df.resample('D').mean()
    return df

# %%
baro_2010_atlantic_max = clean_baro_max(baro_2010_atlantic)
baro_2011_atlantic_max = clean_baro_max(baro_2011_atlantic)
baro_2012_atlantic_max = clean_baro_max(baro_2012_atlantic)
baro_2013_atlantic_max = clean_baro_max(baro_2013_atlantic)
baro_2014_atlantic_max = clean_baro_max(baro_2014_atlantic)
baro_2015_atlantic_max = clean_baro_max(baro_2015_atlantic)
baro_2010_boston_max = clean_baro_max(baro_2010_boston)
baro_2011_boston_max = clean_baro_max(baro_2011_boston)
baro_2012_boston_max = clean_baro_max(baro_2012_boston)
baro_2013_boston_max = clean_baro_max(baro_2013_boston)
baro_2014_boston_max = clean_baro_max(baro_2014_boston)
baro_2015_boston_max = clean_baro_max(baro_2015_boston)
baro_2010_bridgeport_max = clean_baro_max(baro_2010_bridgeport)
baro_2011_bridgeport_max = clean_baro_max(baro_2011_bridgeport)
baro_2012_bridgeport_max = clean_baro_max(baro_2012_bridgeport)
baro_2013_bridgeport_max = clean_baro_max(baro_2013_bridgeport)
baro_2014_bridgeport_max = clean_baro_max(baro_2014_bridgeport)
baro_2015_bridgeport_max = clean_baro_max(baro_2015_bridgeport)
baro_2010_new_haven_max = clean_baro_max(baro_2010_new_haven)
baro_2011_new_haven_max = clean_baro_max(baro_2011_new_haven)
baro_2012_new_haven_max = clean_baro_max(baro_2012_new_haven)
baro_2013_new_haven_max = clean_baro_max(baro_2013_new_haven)
baro_2014_new_haven_max = clean_baro_max(baro_2014_new_haven)
baro_2015_new_haven_max = clean_baro_max(baro_2015_new_haven)
baro_2010_new_london_max = clean_baro_max(baro_2010_new_london)
baro_2011_new_london_max = clean_baro_max(baro_2011_new_london)
baro_2012_new_london_max = clean_baro_max(baro_2012_new_london)
baro_2013_new_london_max = clean_baro_max(baro_2013_new_london)
baro_2014_new_london_max = clean_baro_max(baro_2014_new_london)
baro_2015_new_london_max = clean_baro_max(baro_2015_new_london)
baro_2010_newport_max = clean_baro_max(baro_2010_newport)
baro_2011_newport_max = clean_baro_max(baro_2011_newport)
baro_2012_newport_max = clean_baro_max(baro_2012_newport)
baro_2013_newport_max = clean_baro_max(baro_2013_newport)
baro_2014_newport_max = clean_baro_max(baro_2014_newport)
baro_2015_newport_max = clean_baro_max(baro_2015_newport)
baro_2010_baltimore_max = clean_baro_max(baro_2010_baltimore)
baro_2011_baltimore_max = clean_baro_max(baro_2011_baltimore)
baro_2012_baltimore_max = clean_baro_max(baro_2012_baltimore)
baro_2013_baltimore_max = clean_baro_max(baro_2013_baltimore)
baro_2014_baltimore_max = clean_baro_max(baro_2014_baltimore)
baro_2015_baltimore_max = clean_baro_max(baro_2015_baltimore)
baro_2010_ocean_city_max = clean_baro_max(baro_2010_ocean_city)
baro_2011_ocean_city_max = clean_baro_max(baro_2011_ocean_city)
baro_2012_ocean_city_max = clean_baro_max(baro_2012_ocean_city)
baro_2013_ocean_city_max = clean_baro_max(baro_2013_ocean_city)
baro_2014_ocean_city_max = clean_baro_max(baro_2014_ocean_city)
baro_2015_ocean_city_max = clean_baro_max(baro_2015_ocean_city)
baro_2010_portland_max = clean_baro_max(baro_2010_portland)
baro_2011_portland_max = clean_baro_max(baro_2011_portland)
baro_2012_portland_max = clean_baro_max(baro_2012_portland)
baro_2013_portland_max = clean_baro_max(baro_2013_portland)
baro_2014_portland_max = clean_baro_max(baro_2014_portland)
baro_2015_portland_max = clean_baro_max(baro_2015_portland)
baro_2010_providence_max = clean_baro_max(baro_2010_providence)
baro_2011_providence_max = clean_baro_max(baro_2011_providence)
baro_2012_providence_max = clean_baro_max(baro_2012_providence)
baro_2013_providence_max = clean_baro_max(baro_2013_providence)
baro_2014_providence_max = clean_baro_max(baro_2014_providence)
baro_2015_providence_max = clean_baro_max(baro_2015_providence)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
baro_2010_atlantic_mean = clean_baro_mean(baro_2010_atlantic)
baro_2011_atlantic_mean = clean_baro_mean(baro_2011_atlantic)
baro_2012_atlantic_mean = clean_baro_mean(baro_2012_atlantic)
baro_2013_atlantic_mean = clean_baro_mean(baro_2013_atlantic)
baro_2014_atlantic_mean = clean_baro_mean(baro_2014_atlantic)
baro_2015_atlantic_mean = clean_baro_mean(baro_2015_atlantic)
baro_2010_boston_mean = clean_baro_mean(baro_2010_boston)
baro_2011_boston_mean = clean_baro_mean(baro_2011_boston)
baro_2012_boston_mean = clean_baro_mean(baro_2012_boston)
baro_2013_boston_mean = clean_baro_mean(baro_2013_boston)
baro_2014_boston_mean = clean_baro_mean(baro_2014_boston)
baro_2015_boston_mean = clean_baro_mean(baro_2015_boston)
baro_2010_bridgeport_mean = clean_baro_mean(baro_2010_bridgeport)
baro_2011_bridgeport_mean = clean_baro_mean(baro_2011_bridgeport)
baro_2012_bridgeport_mean = clean_baro_mean(baro_2012_bridgeport)
baro_2013_bridgeport_mean = clean_baro_mean(baro_2013_bridgeport)
baro_2014_bridgeport_mean = clean_baro_mean(baro_2014_bridgeport)
baro_2015_bridgeport_mean = clean_baro_mean(baro_2015_bridgeport)
baro_2010_new_haven_mean = clean_baro_mean(baro_2010_new_haven)
baro_2011_new_haven_mean = clean_baro_mean(baro_2011_new_haven)
baro_2012_new_haven_mean = clean_baro_mean(baro_2012_new_haven)
baro_2013_new_haven_mean = clean_baro_mean(baro_2013_new_haven)
baro_2014_new_haven_mean = clean_baro_mean(baro_2014_new_haven)
baro_2015_new_haven_mean = clean_baro_mean(baro_2015_new_haven)
baro_2010_new_london_mean = clean_baro_mean(baro_2010_new_london)
baro_2011_new_london_mean = clean_baro_mean(baro_2011_new_london)
baro_2012_new_london_mean = clean_baro_mean(baro_2012_new_london)
baro_2013_new_london_mean = clean_baro_mean(baro_2013_new_london)
baro_2014_new_london_mean = clean_baro_mean(baro_2014_new_london)
baro_2015_new_london_mean = clean_baro_mean(baro_2015_new_london)
baro_2010_newport_mean = clean_baro_mean(baro_2010_newport)
baro_2011_newport_mean = clean_baro_mean(baro_2011_newport)
baro_2012_newport_mean = clean_baro_mean(baro_2012_newport)
baro_2013_newport_mean = clean_baro_mean(baro_2013_newport)
baro_2014_newport_mean = clean_baro_mean(baro_2014_newport)
baro_2015_newport_mean = clean_baro_mean(baro_2015_newport)
baro_2010_baltimore_mean = clean_baro_mean(baro_2010_baltimore)
baro_2011_baltimore_mean = clean_baro_mean(baro_2011_baltimore)
baro_2012_baltimore_mean = clean_baro_mean(baro_2012_baltimore)
baro_2013_baltimore_mean = clean_baro_mean(baro_2013_baltimore)
baro_2014_baltimore_mean = clean_baro_mean(baro_2014_baltimore)
baro_2015_baltimore_mean = clean_baro_mean(baro_2015_baltimore)
baro_2010_ocean_city_mean = clean_baro_mean(baro_2010_ocean_city)
baro_2011_ocean_city_mean = clean_baro_mean(baro_2011_ocean_city)
baro_2012_ocean_city_mean = clean_baro_mean(baro_2012_ocean_city)
baro_2013_ocean_city_mean = clean_baro_mean(baro_2013_ocean_city)
baro_2014_ocean_city_mean = clean_baro_mean(baro_2014_ocean_city)
baro_2015_ocean_city_mean = clean_baro_mean(baro_2015_ocean_city)
baro_2010_portland_mean = clean_baro_mean(baro_2010_portland)
baro_2011_portland_mean = clean_baro_mean(baro_2011_portland)
baro_2012_portland_mean = clean_baro_mean(baro_2012_portland)
baro_2013_portland_mean = clean_baro_mean(baro_2013_portland)
baro_2014_portland_mean = clean_baro_mean(baro_2014_portland)
baro_2015_portland_mean = clean_baro_mean(baro_2015_portland)
baro_2010_providence_mean = clean_baro_mean(baro_2010_providence)
baro_2011_providence_mean = clean_baro_mean(baro_2011_providence)
baro_2012_providence_mean = clean_baro_mean(baro_2012_providence)
baro_2013_providence_mean = clean_baro_mean(baro_2013_providence)
baro_2014_providence_mean = clean_baro_mean(baro_2014_providence)
baro_2015_providence_mean = clean_baro_mean(baro_2015_providence)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
atlantic_baro_max = pd.concat([baro_2010_atlantic_max, baro_2011_atlantic_max, baro_2012_atlantic_max, baro_2013_atlantic_max, baro_2014_atlantic_max, baro_2015_atlantic_max])
boston_baro_max = pd.concat([baro_2010_boston_max, baro_2011_boston_max, baro_2012_boston_max, baro_2013_boston_max, baro_2014_boston_max, baro_2015_boston_max])
bridgeport_baro_max = pd.concat([baro_2010_bridgeport_max, baro_2011_bridgeport_max, baro_2012_bridgeport_max, baro_2013_bridgeport_max, baro_2014_bridgeport_max, baro_2015_bridgeport_max])
new_haven_baro_max = pd.concat([baro_2010_new_haven_max, baro_2011_new_haven_max, baro_2012_new_haven_max, baro_2013_new_haven_max, baro_2014_new_haven_max, baro_2015_new_haven_max])
new_london_baro_max = pd.concat([baro_2010_new_london_max, baro_2011_new_london_max, baro_2012_new_london_max, baro_2013_new_london_max, baro_2014_new_london_max, baro_2015_new_london_max])
newport_baro_max = pd.concat([baro_2010_newport_max, baro_2011_newport_max, baro_2012_newport_max, baro_2013_newport_max, baro_2014_newport_max, baro_2015_newport_max])
baltimore_baro_max = pd.concat([baro_2010_baltimore_max, baro_2011_baltimore_max, baro_2012_baltimore_max, baro_2013_baltimore_max, baro_2014_baltimore_max, baro_2015_baltimore_max])
ocean_city_baro_max = pd.concat([baro_2010_ocean_city_max, baro_2011_ocean_city_max, baro_2012_ocean_city_max, baro_2013_ocean_city_max, baro_2014_ocean_city_max, baro_2015_ocean_city_max])
portland_baro_max = pd.concat([baro_2010_portland_max, baro_2011_portland_max, baro_2012_portland_max, baro_2013_portland_max, baro_2014_portland_max, baro_2015_portland_max])
providence_baro_max = pd.concat([baro_2010_providence_max, baro_2011_providence_max, baro_2012_providence_max, baro_2013_providence_max, baro_2014_providence_max, baro_2015_providence_max])

# %%
atlantic_baro_mean = pd.concat([baro_2010_atlantic_mean, baro_2011_atlantic_mean, baro_2012_atlantic_mean, baro_2013_atlantic_mean, baro_2014_atlantic_mean, baro_2015_atlantic_mean])
boston_baro_mean = pd.concat([baro_2010_boston_mean, baro_2011_boston_mean, baro_2012_boston_mean, baro_2013_boston_mean, baro_2014_boston_mean, baro_2015_boston_mean])
bridgeport_baro_mean = pd.concat([baro_2010_bridgeport_mean, baro_2011_bridgeport_mean, baro_2012_bridgeport_mean, baro_2013_bridgeport_mean, baro_2014_bridgeport_mean, baro_2015_bridgeport_mean])
new_haven_baro_mean = pd.concat([baro_2010_new_haven_mean, baro_2011_new_haven_mean, baro_2012_new_haven_mean, baro_2013_new_haven_mean, baro_2014_new_haven_mean, baro_2015_new_haven_mean])
new_london_baro_mean = pd.concat([baro_2010_new_london_mean, baro_2011_new_london_mean, baro_2012_new_london_mean, baro_2013_new_london_mean, baro_2014_new_london_mean, baro_2015_new_london_mean])
newport_baro_mean = pd.concat([baro_2010_newport_mean, baro_2011_newport_mean, baro_2012_newport_mean, baro_2013_newport_mean, baro_2014_newport_mean, baro_2015_newport_mean])
baltimore_baro_mean = pd.concat([baro_2010_baltimore_mean, baro_2011_baltimore_mean, baro_2012_baltimore_mean, baro_2013_baltimore_mean, baro_2014_baltimore_mean, baro_2015_baltimore_mean])
ocean_city_baro_mean = pd.concat([baro_2010_ocean_city_mean, baro_2011_ocean_city_mean, baro_2012_ocean_city_mean, baro_2013_ocean_city_mean, baro_2014_ocean_city_mean, baro_2015_ocean_city_mean])
portland_baro_mean = pd.concat([baro_2010_portland_mean, baro_2011_portland_mean, baro_2012_portland_mean, baro_2013_portland_mean, baro_2014_portland_mean, baro_2015_portland_mean])
providence_baro_mean = pd.concat([baro_2010_providence_mean, baro_2011_providence_mean, baro_2012_providence_mean, baro_2013_providence_mean, baro_2014_providence_mean, baro_2015_providence_mean])

# %%
atlantic = pd.merge(atlantic_tide_max, atlantic_baro_max, on='Date')
boston = pd.merge(boston_tide_max, boston_baro_max, on='Date')
bridgeport = pd.merge(bridgeport_tide_max, bridgeport_baro_max, on='Date')
new_haven = pd.merge(new_haven_tide_max, new_haven_baro_max, on='Date')
new_london = pd.merge(new_london_tide_max, new_london_baro_max, on='Date')
newport = pd.merge(newport_tide_max, newport_baro_max, on='Date')
baltimore = pd.merge(baltimore_tide_max, baltimore_baro_max, on='Date')
ocean_city = pd.merge(ocean_city_tide_max, ocean_city_baro_max, on='Date')
portland = pd.merge(portland_tide_max, portland_baro_max, on='Date')
providence = pd.merge(providence_tide_max, providence_baro_max, on='Date')

# %%
atlantic_mean = pd.merge(atlantic_tide_mean, atlantic_baro_mean, on='Date')
boston_mean = pd.merge(boston_tide_mean, boston_baro_mean, on='Date')
bridgeport_mean = pd.merge(bridgeport_tide_mean, bridgeport_baro_mean, on='Date')
new_haven_mean = pd.merge(new_haven_tide_mean, new_haven_baro_mean, on='Date')
new_london_mean = pd.merge(new_london_tide_mean, new_london_baro_mean, on='Date')
newport_mean = pd.merge(newport_tide_mean, newport_baro_mean, on='Date')
baltimore_mean = pd.merge(baltimore_tide_mean, baltimore_baro_mean, on='Date')
ocean_city_mean = pd.merge(ocean_city_tide_mean, ocean_city_baro_mean, on='Date')
portland_mean = pd.merge(portland_tide_mean, portland_baro_mean, on='Date')
providence_mean = pd.merge(providence_tide_mean, providence_baro_mean, on='Date')

# %%
atlantic_unemploy = pd.read_csv('./data/Atlantic_city_data/unemployment_nonseaonal.csv')
boston_unemploy = pd.read_csv('./data/Boston/unemployment_nonseasonal.csv')
bridgeport_unemploy = pd.read_csv('./data/bridgeport_data/unemployment_nonseasonal.csv')
new_haven_unemploy = pd.read_csv('./data/new_haven_data/unemployment_nonseasonal.csv')
new_london_unemploy = pd.read_csv('./data/new_london_data/unemployment_nonseasonal.csv')
newport_unemploy = pd.read_csv('./data/newport/unemployment_nonseasonal.csv')
baltimore_unemploy = pd.read_csv('./data/baltimore_data/unemployment_nonseasonal.csv')
ocean_city_unemploy = pd.read_csv('./data/ocean_city/unemployment_nonseasonal.csv')
portland_unemploy = pd.read_csv('./data/portland/unemployment_nonseasonal.csv')
providence_unemploy = pd.read_csv('./data/providence/unemployment_nonseasonal.csv')

# %%
def clean_unemploy(df, noaa_data):
    df.columns = ['Date', 'unemployment_rate']
    df['Date'] = df['Date'].map(lambda x: x[:7])
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.set_index('Date')
    df['unemployment_rate'] = pd.to_numeric(df['unemployment_rate'])
    list_days = noaa_data.index
    rate_list = [df.loc[str(i)[:7]]['unemployment_rate'].item() for i in list_days]
    unemploy_df = pd.DataFrame(data=rate_list, index=list_days)
    unemploy_df.rename(columns={0: 'rate'}, inplace=True)
    return unemploy_df

# %%
atlantic_unemploy_df = clean_unemploy(atlantic_unemploy, atlantic)
boston_unemploy_df = clean_unemploy(boston_unemploy, boston)
bridgeport_unemploy_df = clean_unemploy(bridgeport_unemploy, bridgeport)
new_haven_unemploy_df = clean_unemploy(new_haven_unemploy, new_haven)
new_london_unemploy_df = clean_unemploy(new_london_unemploy, new_london)
newport_unemploy_df = clean_unemploy(newport_unemploy, newport)
baltimore_unemploy_df = clean_unemploy(baltimore_unemploy, baltimore)
ocean_city_uneploy_df = clean_unemploy(ocean_city_unemploy, ocean_city)
portland_unemploy_df = clean_unemploy(portland_unemploy, portland)
providence_unemploy_df = clean_unemploy(providence_unemploy, providence)

# %%
atlantic_city = pd.merge(atlantic, atlantic_unemploy_df, on='Date')
boston = pd.merge(boston, boston_unemploy_df, on='Date')
bridgeport = pd.merge(bridgeport, bridgeport_unemploy_df, on='Date')
new_haven = pd.merge(new_haven, new_haven_unemploy_df, on='Date')
new_london = pd.merge(new_london, new_london_unemploy_df, on='Date')
newport = pd.merge(newport, newport_unemploy_df, on='Date')
baltimore = pd.merge(baltimore, baltimore_unemploy_df, on='Date')
ocean_city = pd.merge(ocean_city, ocean_city_uneploy_df, on='Date')
portland = pd.merge(portland, portland_unemploy_df, on='Date')
providence = pd.merge(providence, providence_unemploy_df, on='Date')

# %%
atlantic_city_mean = pd.merge(atlantic_mean, atlantic_unemploy_df, on='Date')
boston_mean = pd.merge(boston_mean, boston_unemploy_df, on='Date')
bridgeport_mean = pd.merge(bridgeport_mean, bridgeport_unemploy_df, on='Date')
new_haven_mean = pd.merge(new_haven_mean, new_haven_unemploy_df, on='Date')
new_london_mean = pd.merge(new_london_mean, new_london_unemploy_df, on='Date')
newport_mean = pd.merge(newport_mean, newport_unemploy_df, on='Date')
baltimore_mean = pd.merge(baltimore_mean, baltimore_unemploy_df, on='Date')
ocean_city_mean = pd.merge(ocean_city_mean, ocean_city_uneploy_df, on='Date')
portland_mean = pd.merge(portland_mean, portland_unemploy_df, on='Date')
providence_mean = pd.merge(providence_mean, providence_unemploy_df, on='Date')

# %%
atlantic_unemploy_df
# Out:
#             rate
# Date
# 2010-01-01  13.9
# 2010-01-02  13.9
# 2010-01-03  13.9
# 2010-01-04  13.9
# 2010-01-05  13.9
# 2010-01-06  13.9
# 2010-01-07  13.9
# 2010-01-08  13.9
# 2010-01-09  13.9
# 2010-01-10  13.9
# 2010-01-11  13.9
# 2010-01-12  13.9
# 2010-01-13  13.9
# 2010-01-14  13.9
# 2010-01-15  13.9
# 2010-01-16  13.9
# 2010-01-17  13.9
# 2010-01-18  13.9
# 2010-01-19  13.9
# 2010-01-20  13.9
# 2010-01-21  13.9
# 2010-01-22  13.9
# 2010-01-23  13.9
# 2010-01-24  13.9
# 2010-01-25  13.9
# 2010-01-26  13.9
# 2010-01-27  13.9
# 2010-01-28  13.9
# 2010-01-29  13.9
# 2010-01-30  13.9
# ...          ...
# 2015-12-02   7.7
# 2015-12-03   7.7
# 2015-12-04   7.7
# 2015-12-05   7.7
# 2015-12-06   7.7
# 2015-12-07   7.7
# 2015-12-08   7.7
# 2015-12-09   7.7
# 2015-12-10   7.7
# 2015-12-11   7.7
# 2015-12-12   7.7
# 2015-12-13   7.7
# 2015-12-14   7.7
# 2015-12-15   7.7
# 2015-12-16   7.7
# 2015-12-17   7.7
# 2015-12-18   7.7
# 2015-12-19   7.7
# 2015-12-20   7.7
# 2015-12-21   7.7
# ...

# %%
atlantic_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/atlantic-city-nj.csv')
baltimore_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/baltimore-md.csv')
boston_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/boston-ma.csv')
bridgeport_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/bridgeport-ct.csv')
new_haven_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/new-haven-ct.csv')
new_london_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/new-london-ct.csv')
newport_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/newport-ri.csv')
portland_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/portland-me.csv')
ocean_city_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/ocean-city-md.csv')
providence_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/providence-ri.csv')
new_bedford_prep = pd.read_csv('./noaa-precip-wind-csv-raw-data/new-bedford-ma.csv')

# %%
def clean_prep(df):
    
    df = df.loc[:, ["DATE", "PRCP", "WSF2", "WSF5"]]
    
    df.rename(columns={'DATE': 'Date'}, inplace=True)
        
    df = df.set_index("Date")
    
    df.index = pd.to_datetime(df.index)
        
    return df

# %%
atlantic_prep_max = clean_prep(atlantic_prep)
baltimore_prep_max = clean_prep(baltimore_prep)
boston_prep_max = clean_prep(boston_prep)
bridgeport_prep_max = clean_prep(bridgeport_prep)
new_haven_prep_max = clean_prep(new_haven_prep)
new_london_prep_max = clean_prep(new_london_prep)
newport_prep_max = clean_prep(newport_prep)
portland_prep_max = clean_prep(portland_prep)
ocean_city_prep_max = clean_prep(ocean_city_prep)
providence_prep_max = clean_prep(providence_prep)
new_bedford_prep_max = clean_prep(new_bedford_prep)

# %%
atlantic_city.index
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-25',
#                '2015-12-26', '2015-12-27', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', name='Date', length=2191, freq=None)

# %%
atlantic_city = pd.merge(atlantic_city, atlantic_prep_max, on='Date')
boston = pd.merge(boston, boston_prep_max, on='Date')
bridgeport = pd.merge(bridgeport, bridgeport_prep_max, on='Date')
new_haven = pd.merge(new_haven, new_haven_prep_max, on='Date')
new_london = pd.merge(new_london, new_london_prep_max, on='Date')
newport = pd.merge(newport, newport_prep_max, on='Date')
baltimore = pd.merge(baltimore, baltimore_prep_max, on='Date')
ocean_city = pd.merge(ocean_city, ocean_city_prep_max, on='Date')
portland = pd.merge(portland, portland_prep_max, on='Date')
providence = pd.merge(providence, providence_prep_max, on='Date')

# %%
atlantic_city_mean = pd.merge(atlantic_city_mean, atlantic_prep_max, on='Date')
boston_mean = pd.merge(boston_mean, boston_prep_max, on='Date')
bridgeport_mean = pd.merge(bridgeport_mean, bridgeport_prep_max, on='Date')
new_haven_mean = pd.merge(new_haven_mean, new_haven_prep_max, on='Date')
new_london_mean = pd.merge(new_london_mean, new_london_prep_max, on='Date')
newport_mean = pd.merge(newport_mean, newport_prep_max, on='Date')
baltimore_mean = pd.merge(baltimore_mean, baltimore_prep_max, on='Date')
ocean_city_mean = pd.merge(ocean_city_mean, ocean_city_prep_max, on='Date')
portland_mean = pd.merge(portland_mean, portland_prep_max, on='Date')
providence_mean = pd.merge(providence_mean, providence_prep_max, on='Date')

# %%
atlantic_city = atlantic_city.resample('M').max()
boston = boston.resample('M').max()
bridgeport = bridgeport.resample('M').max()
new_haven = new_haven.resample('M').max()
new_london = new_london.resample('M').max()
newport = newport.resample('M').max()
baltimore = baltimore.resample('M').max()
ocean_city = ocean_city.resample('M').max()
portland = portland.resample('M').max()
providence = portland.resample('M').max()

# %%
atlantic_city_mean = atlantic_city_mean.resample('M').mean()
boston_mean = boston_mean.resample('M').mean()
bridgeport_mean = bridgeport_mean.resample('M').mean()
new_haven_mean = new_haven_mean.resample('M').mean()
new_london_mean = new_london_mean.resample('M').mean()
newport_mean = newport_mean.resample('M').mean()
baltimore_mean = baltimore_mean.resample('M').mean()
ocean_city_mean = ocean_city_mean.resample('M').mean()
portland_mean = portland_mean.resample('M').mean()
providence_mean = portland_mean.resample('M').mean()

# %%
atlantic_wage = pd.read_csv('./bls-api-data/AtlanticCity2010-2015.csv')
boston_wage = pd.read_csv('./bls-api-data/Boston2010-2015.csv')
bridgeport_wage = pd.read_csv('./bls-api-data/Bridgeport2010-2015.csv')
new_haven_wage = pd.read_csv('./bls-api-data/NewHaven2010-2015.csv')
new_london_wage = pd.read_csv('./bls-api-data/NewLondon2010-2015.csv')
newport_wage = pd.read_csv('./bls-api-data/Newport2010-2015.csv')
baltimore_wage = pd.read_csv('./bls-api-data/Baltimore2010-2015.csv')
ocean_city_wage = pd.read_csv('./bls-api-data/WorcesterCounty2010-2015.csv')
portland_wage = pd.read_csv('./bls-api-data/Portland2010-2015.csv')
providence_wage = pd.read_csv('./bls-api-data/Providence2010-2015.csv')

# %%
def clean_wage(df):
    df.rename(columns={'date': 'Date'}, inplace=True)
    df.drop('Unnamed: 0', axis=1, inplace=True)
    #df['Date'] = pd.to_datetime(df['Date'])
    df = df.set_index('Date')
    df.index = pd.to_datetime(df.index)
    return df

# %%
atlantic_wage = clean_wage(atlantic_wage)
boston_wage = clean_wage(boston_wage)
bridgeport_wage = clean_wage(bridgeport_wage)
new_haven_wage = clean_wage(new_haven_wage)
new_london_wage = clean_wage(new_london_wage)
newport_wage = clean_wage(newport_wage)
baltimore_wage = clean_wage(baltimore_wage)
ocean_city_wage = clean_wage(ocean_city_wage)
portland_wage = clean_wage(portland_wage)
providence_wage = clean_wage(providence_wage)

# %%
atlantic_wage = atlantic_wage.resample('M').mean()
boston_wage = boston_wage.resample('M').mean()
bridgeport_wage = bridgeport_wage.resample('M').mean()
new_haven_wage = new_haven_wage.resample('M').mean()
new_london_wage = new_london_wage.resample('M').mean()
newport_wage = newport_wage.resample('M').mean()
baltimore_wage = baltimore_wage.resample('M').mean()
ocean_city_wage = ocean_city_wage.resample('M').mean()
portland_wage = portland_wage.resample('M').mean()
providence_wage = providence_wage.resample('M').mean()

# %%
atlantic_city_max = pd.merge(atlantic_city, atlantic_wage, on='Date')
boston_max = pd.merge(boston, boston_wage, on='Date')
bridgeport_max = pd.merge(bridgeport, bridgeport_wage, on='Date')
new_haven_max = pd.merge(new_haven, new_haven_wage, on='Date')
new_london_max = pd.merge(new_london, new_london_wage, on='Date')
newport_max = pd.merge(newport, newport_wage, on='Date')
baltimore_max = pd.merge(baltimore, baltimore_wage, on='Date')
ocean_city_max = pd.merge(ocean_city, ocean_city_wage, on='Date')
portland_max = pd.merge(portland, portland_wage, on='Date')
providence_max = pd.merge(providence, providence_wage, on='Date')

# %%
atlantic_city_mean = pd.merge(atlantic_city_mean, atlantic_wage, on='Date')
boston_mean = pd.merge(boston_mean, boston_wage, on='Date')
bridgeport_mean = pd.merge(bridgeport_mean, bridgeport_wage, on='Date')
new_haven_mean = pd.merge(new_haven_mean, new_haven_wage, on='Date')
new_london_mean = pd.merge(new_london_mean, new_london_wage, on='Date')
newport_mean = pd.merge(newport_mean, newport_wage, on='Date')
baltimore_mean = pd.merge(baltimore_mean, baltimore_wage, on='Date')
ocean_city_mean = pd.merge(ocean_city_mean, ocean_city_wage, on='Date')
portland_mean = pd.merge(portland_mean, portland_wage, on='Date')
providence_mean = pd.merge(providence_mean, providence_wage, on='Date')

# %%
atlantic_city_max.columns
# Out:
# Index(['Verified (ft) Max', 'baro', 'rate', 'PRCP', 'WSF2', 'WSF5',
#        'natural_resources_mining_all_employees',
#        'natural_resources_mining_avg_monthly_pay',
#        'natural_resources_mining_aggr_value', 'construction_all_employees',
#        'construction_avg_monthly_pay', 'construction_aggr_value',
#        'manufacturing_all_employees', 'manufacturing_avg_monthly_pay',
#        'manufacturing_aggr_value',
#        'trade_transportation_utilities_all_employees',
#        'trade_transportation_utilities_avg_monthly_pay',
#        'trade_transportation_utilities_aggr_value',
#        'information_all_employees', 'information_avg_monthly_pay',
#        'information_aggr_value', 'financial_activities_all_employees',
#        'financial_activities_avg_monthly_pay',
#        'financial_activities_aggr_value',
#        'professional_business_services_all_employees',
#        'professional_business_services_avg_monthly_pay',
# ...

# %%
plt.figure(figsize=(25, 15))
plt.plot(boston_max['natural_resources_mining_avg_monthly_pay'], label='natural resources')
plt.plot(boston_max['construction_avg_monthly_pay'], label='construction')
plt.plot(boston_max['manufacturing_avg_monthly_pay'], label='manufacturing')
plt.plot(boston_max['trade_transportation_utilities_avg_monthly_pay'], label='trade transportation')
plt.plot(boston_max['information_avg_monthly_pay'], label='information')
plt.plot(boston_max['financial_activities_avg_monthly_pay'], label='finance')
plt.plot(boston_max['professional_business_services_avg_monthly_pay'], label='professional business services')
plt.plot(boston_max['education_health_services_avg_monthly_pay'], label='education')
plt.plot(boston_max['leisure_hospitality_avg_monthly_pay'], label='leisure')
plt.plot(boston_max['other_services_avg_monthly_pay'], label='other')
plt.plot(boston_max['unclassified_avg_monthly_pay'], label='unclassified')
plt.xlim(pd.Timestamp('2012-01-31'), pd.Timestamp('2013-01-31'))
plt.legend();
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_city_max['natural_resources_mining_avg_monthly_pay'], label='natural resources')
plt.plot(atlantic_city_max['construction_avg_monthly_pay'], label='construction')
plt.plot(atlantic_city_max['manufacturing_avg_monthly_pay'], label='manufacturing')
plt.plot(atlantic_city_max['trade_transportation_utilities_avg_monthly_pay'], label='trade transportation')
plt.plot(atlantic_city_max['information_avg_monthly_pay'], label='information')
plt.plot(atlantic_city_max['financial_activities_avg_monthly_pay'], label='finance')
plt.plot(atlantic_city_max['professional_business_services_avg_monthly_pay'], label='professional business services')
plt.plot(atlantic_city_max['education_health_services_avg_monthly_pay'], label='education')
plt.plot(atlantic_city_max['leisure_hospitality_avg_monthly_pay'], label='leisure')
plt.plot(atlantic_city_max['other_services_avg_monthly_pay'], label='other')
plt.plot(atlantic_city_max['unclassified_avg_monthly_pay'], label='unclassified')
plt.xlim(pd.Timestamp('2012-01-31'), pd.Timestamp('2013-01-31'))
plt.legend();

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_city_max['rate'], label='Atlantic City')
plt.plot(boston_max['rate'], label='Boston')
plt.plot(bridgeport_max['rate'], label='Bridgeport')
plt.plot(new_haven_max['rate'], label='New Haven')
plt.plot(new_london_max['rate'], label='New London')
plt.plot(newport_max['rate'], label='Newport')
plt.plot(baltimore_max['rate'], label='Baltimore')
plt.plot(ocean_city_max['rate'], label='Ocean City')
plt.plot(portland_max['rate'], label='Portland')
plt.plot(providence_max['rate'], label='Providence')
#plt.xlim(pd.Timestamp('2012-10-01'), pd.Timestamp('2012-12-01'))
plt.title('Unemployment Over Month', fontsize=40)
plt.xlabel('Date', fontsize=30)
plt.legend(fontsize ='xx-large')
plt.ylabel('Unemployment Per Month', fontsize=30);

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_prep_max['PRCP'], label='Atlantic City')
plt.plot(boston_prep_max['PRCP'], label='Boston')
plt.plot(bridgeport_prep_max['PRCP'], label='Bridgeport')
plt.plot(new_haven_prep_max['PRCP'], label='New Haven')
plt.plot(new_london_prep_max['PRCP'], label='New London')
plt.plot(newport_prep_max['PRCP'], label='Newport')
plt.plot(baltimore_prep_max['PRCP'], label='Baltimore')
plt.plot(ocean_city_prep_max['PRCP'], label='Ocean City')
plt.plot(portland_prep_max['PRCP'], label='Portland')
plt.plot(providence_prep_max['PRCP'], label='Providence')
plt.xlim(pd.Timestamp('2012-10-01'), pd.Timestamp('2012-12-01'))
plt.title('Precipitation Per Day', fontsize=40)
plt.xlabel('Date', fontsize=30)
plt.legend(fontsize ='xx-large')
plt.ylabel('Precipitation in Inches', fontsize=30);

# %%
plt.figure(figsize=(12, 12))
plt.plot(atlantic_city_max['baro'], label='atlantic city')
plt.plot(boston_max['baro'], label='boston')
plt.plot(bridgeport_max['baro'], label='bridgeport')
plt.plot(new_haven_max['baro'], label='new haven')
plt.plot(new_london_max['baro'], label='new london')
plt.plot(newport_max['baro'], label='newport')
plt.plot(baltimore_max['baro'], label='baltimore')
plt.plot(ocean_city_max['baro'], label='ocean city')
plt.plot(portland_max['baro'], label='portland')
plt.plot(providence_max['baro'], label='providence')

plt.legend()

# %%
plt.figure(figsize=(12, 12))
plt.plot(atlantic_city_max['Verified (ft) Max'], label='atlantic city')
plt.plot(boston_max['Verified (ft) Max'], label='boston')
plt.plot(bridgeport_max['Verified (ft) Max'], label='bridgeport')
plt.plot(new_haven_max['Verified (ft) Max'], label='new haven')
plt.plot(new_london_max['Verified (ft) Max'], label='new london')
plt.plot(newport_max['Verified (ft) Max'], label='newport')
plt.plot(baltimore_max['Verified (ft) Max'], label='baltimore')
plt.plot(ocean_city_max['Verified (ft) Max'], label='ocean city')
plt.plot(portland_max['Verified (ft) Max'], label='portland')
plt.plot(providence_max['Verified (ft) Max'], label='providence')
plt.xlim(pd.Timestamp('2012-8-01'), pd.Timestamp('2013-01-15'))
plt.legend()

# %%
plt.figure(figsize=(12, 12))
plt.plot(atlantic_prep_max['WSF5'], label='atlantic city')
plt.plot(boston_prep_max['WSF5'], label='boston')
plt.plot(bridgeport_prep_max['WSF5'], label='bridgeport')
plt.plot(new_haven_prep_max['WSF5'], label='new haven')
plt.plot(new_london_prep_max['WSF5'], label='new london')
plt.plot(newport_prep_max['WSF5'], label='newport')
plt.plot(baltimore_prep_max['WSF5'], label='baltimore')
plt.plot(ocean_city_prep_max['WSF5'], label='ocean city')
plt.plot(portland_prep_max['WSF5'], label='portland')
plt.plot(providence_prep_max['WSF5'], label='providence')
plt.xlim(pd.Timestamp('2012-10-25'), pd.Timestamp('2012-11-10'))
plt.legend()

# %%
from statsmodels.tsa.arima_model import ARIMA 
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

arima1 = ARIMA(endog=boston_max['financial_activities_avg_monthly_pay'], order=(6, 0, 1))
ar1 = arima1.fit()
predictions = ar1.predict()

mean_squared_error(boston_max['financial_activities_avg_monthly_pay'], predictions)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# 1219530.9892091716

# %%
plt.plot(boston_max['financial_activities_avg_monthly_pay'])

# %%
from statsmodels.tsa.stattools import adfuller

# Code written by Joseph Nelson.

def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

interpret_dftest(adfuller(boston_max['financial_activities_aggr_value']))
# Out:
# Test Statistic    0.701346
# p-value           0.989865
# dtype: float64

# %%
# Write a for loop to find the lowest difference value d.

# Iterate through all possible differences.
for d in range(1, len(boston_max['financial_activities_aggr_value'])):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["financial_activities_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')

          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['financial_activities_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 0.0006259179888068666.
# Differencing our time series by d=1 yields a stationary time series!

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, ax = plt.subplots(figsize=(9,5))

# Generate plot.
plot_acf(boston_max["financial_activities_aggr_value"].diff(12).dropna(), lags=30, ax=ax);

# %%
# Set figure/axes.
fig, ax = plt.subplots(figsize=(9,5))

# Generate plot.
plot_pacf(boston_max["financial_activities_aggr_value"].diff(12).dropna(), lags=20, ax=ax);
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
model = SARIMAX(endog = boston_max['financial_activities_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)

# %%
model_fit = model.fit()
y_hat_boston_finance = model_fit.predict()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
plt.plot(boston_max['financial_activities_aggr_value']), plt.plot(y_hat_boston_finance)
# Out:
# ([<matplotlib.lines.Line2D at 0x12a721ba8>],
#  [<matplotlib.lines.Line2D at 0x12a6fd748>])

# %%
interpret_dftest(adfuller(boston_max['construction_aggr_value'].diff(12).dropna()))
# Out:
# Test Statistic   -1.961294
# p-value           0.303798
# dtype: float64

# %%
for d in range(1, len(boston_max['construction_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["construction_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['construction_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 4.097692484251045e-06.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['construction_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_construction = model_fit.predict()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
plt.plot(boston_max['construction_aggr_value']), plt.plot(y_hat_boston_construction)
# Out:
# ([<matplotlib.lines.Line2D at 0x12ae74358>],
#  [<matplotlib.lines.Line2D at 0x12adaad68>])

# %%
interpret_dftest(adfuller(boston_max['natural_resources_mining_aggr_value'].diff(12).dropna()))
# Out:
# Test Statistic   -2.881320
# p-value           0.047564
# dtype: float64

# %%
for d in range(1, len(boston_max['natural_resources_mining_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["natural_resources_mining_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['natural_resources_mining_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 8.579740384738036e-11.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['natural_resources_mining_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_natural_resources = model_fit.predict()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
plt.plot(boston_max['natural_resources_mining_aggr_value']), plt.plot(y_hat_boston_natural_resources);

# %%
interpret_dftest(adfuller(boston_max['manufacturing_aggr_value'].diff(12).dropna()))
# Out:
# Test Statistic   -1.961294
# p-value           0.303798
# dtype: float64

# %%
for d in range(1, len(boston_max['manufacturing_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["manufacturing_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['manufacturing_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 0.00010025568647126752.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['manufacturing_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_manufacturing = model_fit.predict()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
plt.plot(boston_max['manufacturing_aggr_value']), plt.plot(y_hat_boston_manufacturing);

# %%
interpret_dftest(adfuller(boston_max['trade_transportation_utilities_aggr_value'].diff(12).dropna()))
# Out:
# Test Statistic   -1.337881
# p-value           0.611668
# dtype: float64

# %%
for d in range(1, len(boston_max['trade_transportation_utilities_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["trade_transportation_utilities_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['trade_transportation_utilities_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 7.758394117899322e-09.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['trade_transportation_utilities_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!

model_fit = model.fit()
y_hat_boston_trade = model_fit.predict()

plt.plot(boston_max['trade_transportation_utilities_aggr_value']), plt.plot(y_hat_boston_trade);
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
interpret_dftest(adfuller(boston_max['information_aggr_value'].diff(12).dropna()))
# Out:
# Test Statistic   -1.813824
# p-value           0.373620
# dtype: float64

# %%
for d in range(1, len(boston_max['information_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["information_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['information_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 0.026106879938465267.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['information_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!

model_fit = model.fit()
y_hat_boston_information = model_fit.predict()
plt.plot(boston_max['information_aggr_value']), plt.plot(y_hat_boston_manufacturing);
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
interpret_dftest(adfuller(boston_max['professional_business_services_aggr_value'].dropna()))
# Out:
# Test Statistic    0.842998
# p-value           0.992299
# dtype: float64

# %%
for d in range(1, len(boston_max['professional_business_services_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["professional_business_services_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['professional_business_services_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 0.0011082083621736728.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['professional_business_services_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_pbs = model_fit.predict()
plt.plot(boston_max['pr']), plt.plot(y_hat_pbs);

# %%
interpret_dftest(adfuller(boston_max['education_health_services_avg_monthly_pay'].dropna()))
# Out:
# Test Statistic   -0.713246
# p-value           0.843289
# dtype: float64

# %%
for d in range(1, len(boston_max['education_health_services_avg_monthly_pay'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["education_health_services_avg_monthly_pay"].diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['education_health_services_avg_monthly_pay'].diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 1.133311783455955e-29.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['education_health_services_avg_monthly_pay'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 0, 0, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_manufacturing = model_fit.predict()
plt.plot(boston_max['education_health_services_avg_monthly_pay']), plt.plot(y_hat_boston_manufacturing);

# %%
interpret_dftest(adfuller(boston_max['leisure_hospitality_avg_monthly_pay'].dropna()))
# Out:
# Test Statistic    1.744392
# p-value           0.998232
# dtype: float64

# %%
for d in range(1, len(boston_max['leisure_hospitality_avg_monthly_pay'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["leisure_hospitality_avg_monthly_pay"].diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['leisure_hospitality_avg_monthly_pay'].diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 1.6582696231646875e-13.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['leisure_hospitality_avg_monthly_pay'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 0, 0, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_manufacturing = model_fit.predict()
plt.plot(boston_max['leisure_hospitality_avg_monthly_pay']), plt.plot(y_hat_boston_manufacturing);

# %%
interpret_dftest(adfuller(boston_max['other_services_avg_monthly_pay'].dropna()))
# Out:
# Test Statistic    0.227345
# p-value           0.973754
# dtype: float64

# %%
for d in range(1, len(boston_max['other_services_avg_monthly_pay'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["other_services_avg_monthly_pay"].diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['other_services_avg_monthly_pay'].diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 0.235117025686439.
#
# Checking difference of 2.
# p-value = 0.227781812576121.
#
# Checking difference of 3.
# p-value = 0.2536708934356379.
#
# Checking difference of 4.
# p-value = 0.23442913740631716.
#
# Checking difference of 5.
# p-value = 0.5107006714517828.
#
# Checking difference of 6.
# p-value = 0.23697820911669287.
#
# Checking difference of 7.
# p-value = 0.06648034987454474.
#
# Checking difference of 8.
# p-value = 0.3394978357965732.
#
# Checking difference of 9.
# p-value = 0.5747278928394985.
#
# Checking difference of 10.
# p-value = 0.6505044601456976.
#
# Checking difference of 11.
# p-value = 0.6819919082615087.
#
# Checking difference of 12.
# p-value = 0.17940014360621975.
#
# Checking difference of 13.
# p-value = 0.0065426604956421.
# Differencing our time series by d=13 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['other_services_avg_monthly_pay'].dropna(), # endog = Y variable
              order = (0,13,1), seasonal_order=(0, 0, 0, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_manufacturing = model_fit.predict()
plt.plot(boston_max['other_services_avg_monthly_pay'])
#plt.plot(y_hat_boston_manufacturing);

# %%
interpret_dftest(adfuller(boston_max['unclassified_aggr_value'].diff(12).dropna()))
# Out:
# Test Statistic   -2.530731
# p-value           0.108175
# dtype: float64

# %%
for d in range(1, len(boston_max['unclassified_aggr_value'].dropna())):
    
    # Print out a counter and the corresponding p-value.
    print(f'Checking difference of {d}.')
    print(f'p-value = {interpret_dftest(adfuller(boston_max["unclassified_aggr_value"].diff(12).diff(d).dropna()))["p-value"]}.')
          
    # If our data, differenced by d time periods, are stationary, print that out!
    if interpret_dftest(adfuller(boston_max['unclassified_aggr_value'].diff(12).diff(d).dropna()))['p-value'] < 0.05:
        print(f'Differencing our time series by d={d} yields a stationary time series!')
        break
    
    print()
# Out:
# Checking difference of 1.
# p-value = 2.0245325159719843e-08.
# Differencing our time series by d=1 yields a stationary time series!

# %%
model = SARIMAX(endog = boston_max['unclassified_aggr_value'].dropna(), # endog = Y variable
              order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit()
y_hat_boston_manufacturing = model_fit.predict()
plt.plot(boston_max['unclassified_aggr_value'].diff(12))
plt.plot(y_hat_boston_manufacturing);

# %%
plt.plot(boston_max['unclassified_avg_monthly_pay'])

# %%
wage_cols = [col for col in boston_wage]

# %%
wage = [num.str.contains('aggr', regex=False) for num in wage_cols]
wage
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-92ba2eeee29c> in <module>
# ----> 1 wage = [num.str.contains('aggr', regex=False) for num in wage_cols]
#       2 wage
#
# <ipython-input-172-92ba2eeee29c> in <listcomp>(.0)
# ----> 1 wage = [num.str.contains('aggr', regex=False) for num in wage_cols]
#       2 wage
#
# AttributeError: 'str' object has no attribute 'str'

# %%
def run_sarima(df, col):

    # Iterate through all possible differences.
    for d in range(1, len(df)):

        # Print out a counter and the corresponding p-value.
        print(f'Checking difference of {d}.')
        print(f'p-value = {interpret_dftest(adfuller(df[col].diff(12).diff(d).dropna()))["p-value"]}.')

        # If our data, differenced by d time periods, are stationary, print that out!
        if interpret_dftest(adfuller(df[col].diff(12).diff(d).dropna()))['p-value'] < 0.05:
            print(f'Differencing our time series by d={d} yields a stationary time series!')
            break

        print()

    model = SARIMAX(endog = df[col].dropna(), # endog = Y variable
                  order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!

    model_fit = model.fit()
    y_hat = model_fit.predict()
              
    plt.figure() 
    plt.title(col)
    plt.plot(y_hat);

# %%
wage_cols = [col for col in atlantic_wage.columns if "aggr_value" in col]

# %%
for col in wage_cols:
    run_sarima(bridgeport_wage, col)
# Out:
# Checking difference of 1.
# p-value = 0.0006399144993915833.
# Differencing our time series by d=1 yields a stationary time series!
# Checking difference of 1.
# p-value = 2.508676603377007e-10.
# Differencing our time series by d=1 yields a stationary time series!
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# Checking difference of 1.
# p-value = 4.695169611505158e-09.
# Differencing our time series by d=1 yields a stationary time series!
# Checking difference of 1.
# p-value = 0.0007995639924484605.
# Differencing our time series by d=1 yields a stationary time series!
# Checking difference of 1.
# ...

# %%
for col in wage_cols:
    run_sarima(baltimore_wage, col)
# Out:
# Checking difference of 1.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-e8f67ad3e7b9> in <module>
#       1 for col in wage_cols:
# ----> 2     run_sarima(baltimore_wage, col)
#
# <ipython-input-150-4ac77afe3c21> in run_sarima(df, col)
#       6         # Print out a counter and the corresponding p-value.
#       7         print(f'Checking difference of {d}.')
# ----> 8         print(f'p-value = {interpret_dftest(adfuller(df[col].diff(12).diff(d).dropna()))["p-value"]}.')
#       9
#      10         # If our data, differenced by d time periods, are stationary, print that out!
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     219
#     220     xdiff = np.diff(x)
# --> 221     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
# ...

# %%
run_sarima(new_haven_wage, 'natural_resources_mining_aggr_value')
# Out:
# Checking difference of 1.
# p-value = 2.664564987416221e-13.
# Differencing our time series by d=1 yields a stationary time series!
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
run_sarima(new_london_wage, 'natural_resources_mining_aggr_value')
# Out:
# Checking difference of 1.
# p-value = 6.900196721243138e-16.
# Differencing our time series by d=1 yields a stationary time series!

# %%
run_sarima(providence_wage, 'natural_resources_mining_aggr_value')
# Out:
# Checking difference of 1.
# p-value = 0.47362810541964995.
#
# Checking difference of 2.
# /anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-4ffd7e72f4cd> in <module>
# ----> 1 run_sarima(providence_wage, 'natural_resources_mining_aggr_value')
#
# <ipython-input-150-4ac77afe3c21> in run_sarima(df, col)
#       6         # Print out a counter and the corresponding p-value.
#       7         print(f'Checking difference of {d}.')
# ----> 8         print(f'p-value = {interpret_dftest(adfuller(df[col].diff(12).diff(d).dropna()))["p-value"]}.')
#       9
#      10         # If our data, differenced by d time periods, are stationary, print that out!
#
# ...

# %%
def run_sma(df, col):


    model = SARIMAX(endog = df[col].dropna(), # endog = Y variable
                  order = (0,1,1), seasonal_order=(0, 1, 1, 12), enforce_invertibility=False) # (p, d, q) <-- talk about q later!

    model_fit = model.fit()
    y_hat = model_fit.predict()
              
    plt.figure() 
    plt.title(col)
    plt.plot(y_hat);

# %%
atlantic_wage.columns
# Out:
# Index(['natural_resources_mining_all_employees',
#        'natural_resources_mining_avg_monthly_pay',
#        'natural_resources_mining_aggr_value', 'construction_all_employees',
#        'construction_avg_monthly_pay', 'construction_aggr_value',
#        'manufacturing_all_employees', 'manufacturing_avg_monthly_pay',
#        'manufacturing_aggr_value',
#        'trade_transportation_utilities_all_employees',
#        'trade_transportation_utilities_avg_monthly_pay',
#        'trade_transportation_utilities_aggr_value',
#        'information_all_employees', 'information_avg_monthly_pay',
#        'information_aggr_value', 'financial_activities_all_employees',
#        'financial_activities_avg_monthly_pay',
#        'financial_activities_aggr_value',
#        'professional_business_services_all_employees',
#        'professional_business_services_avg_monthly_pay',
#        'professional_business_services_aggr_value',
#        'education_health_services_all_employees',
# ...

# %%
run_sma(atlantic_wage, 'natural_resources_mining_aggr_value')
