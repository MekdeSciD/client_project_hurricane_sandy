# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
atlantic_unemploy = pd.read_csv('./data/Atlantic_city_data/unemployment_nonseaonal.csv')
boston_unemploy = pd.read_csv('./data/Boston/unemployment_nonseasonal.csv')
bridgeport_unemploy = pd.read_csv('./data/bridgeport_data/unemployment_nonseasonal.csv')
new_haven_unemploy = pd.read_csv('./data/new_haven_data/unemployment_nonseasonal.csv')
new_london_unemploy = pd.read_csv('./data/new_london_data/unemployment_nonseasonal.csv')
newport_unemploy = pd.read_csv('./data/newport/unemployment_nonseasonal.csv')
baltimore_unemploy = pd.read_csv('./data/baltimore_data/unemployment_nonseasonal.csv')
ocean_city_unemploy = pd.read_csv('./data/ocean_city/unemployment_nonseasonal.csv')
portland_unemploy = pd.read_csv('./data/portland/unemployment_nonseasonal.csv')
providence_unemploy = pd.read_csv('./data/providence/unemployment_nonseasonal.csv')

# %%
atlantic_unemploy.set_index('DATE', inplace=True)
atlantic_unemploy.sort_index(inplace=True)  

atlantic_unemploy.head()
# Out:
#             ATLA134URN
# DATE
# 2010-01-01        13.9
# 2010-02-01        13.8
# 2010-03-01        13.1
# 2010-04-01        12.1
# 2010-05-01        11.8

# %%
boston_unemploy.set_index('DATE', inplace=True)
boston_unemploy.sort_index(inplace=True)  

boston_unemploy.head()
# Out:
#             BOST625URN
# DATE
# 2010-01-01         8.6
# 2010-02-01         8.3
# 2010-03-01         8.0
# 2010-04-01         7.6
# 2010-05-01         7.5

# %%
bridgeport_unemploy.set_index('DATE', inplace=True)
bridgeport_unemploy.sort_index(inplace=True)  

bridgeport_unemploy.head()
# Out:
#             BRID909URN
# DATE
# 2010-01-01         9.0
# 2010-02-01         8.9
# 2010-03-01         8.7
# 2010-04-01         8.5
# 2010-05-01         8.4

# %%
new_haven_unemploy.set_index('DATE', inplace=True)
new_haven_unemploy.sort_index(inplace=True)  

new_haven_unemploy.head()
# Out:
#             NEWH709URN
# DATE
# 2010-01-01         9.4
# 2010-02-01         9.4
# 2010-03-01         9.2
# 2010-04-01         9.0
# 2010-05-01         9.0

# %%
new_london_unemploy.set_index('DATE', inplace=True)
new_london_unemploy.sort_index(inplace=True)  

new_london_unemploy.head()
# Out:
#             CTNEWL1URN
# DATE
# 2010-01-01         9.1
# 2010-02-01         9.1
# 2010-03-01         9.0
# 2010-04-01         8.7
# 2010-05-01         8.6

# %%
newport_unemploy.set_index('DATE', inplace=True)
newport_unemploy.sort_index(inplace=True)  

newport_unemploy.head()
# Out:
#             RINEWP5URN
# DATE
# 2010-01-01        12.3
# 2010-02-01        11.9
# 2010-03-01        11.6
# 2010-04-01         9.5
# 2010-05-01         9.1

# %%
baltimore_unemploy.set_index('DATE', inplace=True)
baltimore_unemploy.sort_index(inplace=True)  

baltimore_unemploy.head()
# Out:
#             MDBALT5URN
# DATE
# 2010-01-01        11.3
# 2010-02-01        11.6
# 2010-03-01        11.5
# 2010-04-01        10.6
# 2010-05-01        10.8

# %%
ocean_city_unemploy.set_index('DATE', inplace=True)
ocean_city_unemploy.sort_index(inplace=True)  

ocean_city_unemploy.head()
# Out:
#             MDWORC7URN
# DATE
# 2010-01-01        17.9
# 2010-02-01        18.7
# 2010-03-01        17.1
# 2010-04-01        13.5
# 2010-05-01        11.5

# %%
portland_unemploy.set_index('DATE', inplace=True)
portland_unemploy.sort_index(inplace=True)  

portland_unemploy.head()
# Out:
#             PORT723URN
# DATE
# 2010-01-01         7.7
# 2010-02-01         7.9
# 2010-03-01         7.7
# 2010-04-01         7.0
# 2010-05-01         6.8

# %%
providence_unemploy.set_index('DATE', inplace=True)
providence_unemploy.sort_index(inplace=True)  

providence_unemploy.head()
# Out:
#             RIPROV7URN
# DATE
# 2010-01-01        12.4
# 2010-02-01        12.2
# 2010-03-01        12.1
# 2010-04-01        11.7
# 2010-05-01        11.8
