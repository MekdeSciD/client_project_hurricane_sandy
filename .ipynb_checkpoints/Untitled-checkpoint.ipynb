# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./DisasterDeclarationsSummaries.csv")

# %%
df.head().T
# Out:
#                                                      0  \
# disasterNumber                                       1
# ihProgramDeclared                                    0
# iaProgramDeclared                                    1
# paProgramDeclared                                    1
# hmProgramDeclared                                    1
# state                                               GA
# declarationDate               1953-05-02T00:00:00.000Z
# fyDeclared                                        1953
# disasterType                                        DR
# incidentType                                   Tornado
# title                                          TORNADO
# incidentBeginDate             1953-05-02T00:00:00.000Z
# incidentEndDate               1953-05-02T00:00:00.000Z
# disasterCloseOutDate          1954-06-01T00:00:00.000Z
# declaredCountyArea                                 NaN
# placeCode                                          NaN
# ...

# %%
df.tail().T
# Out:
#                                                         49465  \
# disasterNumber                                           4424
# ihProgramDeclared                                           0
# iaProgramDeclared                                           0
# paProgramDeclared                                           1
# hmProgramDeclared                                           1
# state                                                      OH
# declarationDate                      2019-04-08T10:10:00.000Z
# fyDeclared                                               2019
# disasterType                                               DR
# incidentType                                            Flood
# title                 SEVERE STORMS, FLOODING, AND LANDSLIDES
# incidentBeginDate                    2019-02-05T09:37:41.000Z
# incidentEndDate                      2019-02-13T23:59:00.000Z
# disasterCloseOutDate                                      NaN
# ...
