# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import Series
from pandas import DataFrame
from pandas import TimeGrouper

# %%
atlantic_baro = pd.read_csv("./weather-clean-data-original-time/atlantic_baro.csv")
atlantic_tide = pd.read_csv("./weather-clean-data-original-time/atlantic_tide.csv")
atlantic_prep = pd.read_csv("./weather-clean-data-original-time/atlantic_prep.csv")

# %%
baltimore_baro = pd.read_csv("./weather-clean-data-original-time/baltimore_baro.csv")
baltimore_tide = pd.read_csv("./weather-clean-data-original-time/baltimore_tide.csv")
baltimore_prep = pd.read_csv("./weather-clean-data-original-time/baltimore_prep.csv")

# %%
boston_baro = pd.read_csv("./weather-clean-data-original-time/boston_baro.csv")
boston_tide = pd.read_csv("./weather-clean-data-original-time/boston_tide.csv")
boston_prep = pd.read_csv("./weather-clean-data-original-time/boston_prep.csv")

# %%
bridgeport_baro = pd.read_csv("./weather-clean-data-original-time/bridgeport_baro.csv")
bridgeport_tide = pd.read_csv("./weather-clean-data-original-time/bridgeport_tide.csv")
bridgeport_prep = pd.read_csv("./weather-clean-data-original-time/bridgeport_prep.csv")

# %%
new_haven_baro = pd.read_csv("./weather-clean-data-original-time/new_haven_baro.csv")
new_haven_tide = pd.read_csv("./weather-clean-data-original-time/new_haven_tide.csv")
new_haven_prep = pd.read_csv("./weather-clean-data-original-time/new_haven_prep.csv")

# %%
new_london_baro = pd.read_csv("./weather-clean-data-original-time/new_london_baro.csv")
new_london_tide = pd.read_csv("./weather-clean-data-original-time/new_london_tide.csv")
new_london_prep = pd.read_csv("./weather-clean-data-original-time/new_london_prep.csv")

# %%
ocean_city_baro = pd.read_csv("./weather-clean-data-original-time/ocean_city_baro.csv")
ocean_city_tide = pd.read_csv("./weather-clean-data-original-time/ocean_city_tide.csv")
ocean_city_prep = pd.read_csv("./weather-clean-data-original-time/ocean_city_prep.csv")

# %%
portland_baro = pd.read_csv("./weather-clean-data-original-time/portland_baro.csv")
portland_tide = pd.read_csv("./weather-clean-data-original-time/portland_tide.csv")
portland_prep = pd.read_csv("./weather-clean-data-original-time/portland_prep.csv")

# %%
providence_baro = pd.read_csv("./weather-clean-data-original-time/providence_baro.csv")
providence_tide = pd.read_csv("./weather-clean-data-original-time/providence_tide.csv")
providence_prep = pd.read_csv("./weather-clean-data-original-time/providence_prep.csv")

# %%
providence_prep.head()
# Out:
#          Date  PRCP  WSF2  WSF5
# 0  2010-01-01  0.01  13.0  17.0
# 1  2010-01-02  0.27  25.1  33.1
# 2  2010-01-03  0.04  25.9  36.0
# 3  2010-01-04  0.00  21.9  32.0
# 4  2010-01-05  0.00  14.1  19.9

# %%
providence_baro.head()
# Out:
#                   Date    baro
# 0  2010-01-01 00:00:00  1019.2
# 1  2010-01-01 01:00:00  1018.3
# 2  2010-01-01 02:00:00  1017.8
# 3  2010-01-01 03:00:00  1017.1
# 4  2010-01-01 04:00:00  1016.4

# %%
plt.figure(figsize=(12, 12))

plt.plot(providence_baro['baro'], label='new haven')

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_prep, label='atlantic city')
plt.plot(boston_prep, label='boston')
plt.plot(bridgeport_prep, label='bridgeport')
plt.plot(new_haven_prep, label='new haven')
plt.plot(new_london_prep, label='new london')
plt.plot(newport_prep, label='newport')
plt.plot(baltimore_prep, label='baltimore')
plt.plot(ocean_city_prep, label='ocean city')
plt.plot(portland_prep, label='portland')
plt.plot(providence_prep, label='providence')
plt.xlim(pd.Timestamp('2012-10-26'), pd.Timestamp('2012-11-3'))
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c29979446ea8> in <module>
#       1 plt.figure(figsize=(25, 15))
# ----> 2 plt.plot(atlantic_prep, label='atlantic city')
#       3 plt.plot(boston_prep, label='boston')
#       4 plt.plot(bridgeport_prep, label='bridgeport')
#       5 plt.plot(new_haven_prep, label='new haven')
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     203         if self.axes.xaxis is not None and self.axes.yaxis is not None:
#     204             bx = self.axes.xaxis.update_units(x)
# --> 205             by = self.axes.yaxis.update_units(y)
#     206
#     207             if self.command != 'plot':
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axis.py in update_units(self, data)
#    1471         neednew = self.converter != converter
#    1472         self.converter = converter
# -> 1473         default = self.converter.default_units(data, self)
#    1474         if default is not None and self.units is None:
#    1475             self.set_units(default)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/category.py in default_units(data, axis)
#     101         # default_units->axis_info->convert
#     102         if axis.units is None:
# --> 103             axis.set_units(UnitData(data))
#     104         else:
#     105             axis.units.update(data)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/category.py in __init__(self, data)
#     167         self._counter = itertools.count()
#     168         if data is not None:
# --> 169             self.update(data)
#     170
#     171     def update(self, data):
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/category.py in update(self, data)
#     184         data = np.atleast_1d(np.array(data, dtype=object))
#     185
# --> 186         for val in OrderedDict.fromkeys(data):
#     187             if not isinstance(val, (str, bytes)):
#     188                 raise TypeError("{val!r} is not a string".format(val=val))
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
plt.figure(figsize=(25, 15))
plt.plot(atlantic_baro, label='atlantic city')
plt.plot(boston_baro, label='boston')
plt.plot(bridgeport_baro, label='bridgeport')
plt.plot(new_haven_baro, label='new haven')
plt.plot(new_london_baro, label='new london')
plt.plot(newport_baro, label='newport')
plt.plot(baltimore_baro, label='baltimore')
plt.plot(ocean_city_baro, label='ocean city')
plt.plot(portland_baro, label='portland')
plt.plot(providence_baro, label='providence')
plt.xlim(pd.Timestamp('2012-10-26'), pd.Timestamp('2012-11-3'))
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6e4346b6ebe7> in <module>
#       1 plt.figure(figsize=(25, 15))
# ----> 2 plt.plot(atlantic_baro, label='atlantic city')
#       3 plt.plot(boston_baro, label='boston')
#       4 plt.plot(bridgeport_baro, label='bridgeport')
#       5 plt.plot(new_haven_baro, label='new haven')
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     203         if self.axes.xaxis is not None and self.axes.yaxis is not None:
#     204             bx = self.axes.xaxis.update_units(x)
# --> 205             by = self.axes.yaxis.update_units(y)
#     206
#     207             if self.command != 'plot':
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axis.py in update_units(self, data)
#    1471         neednew = self.converter != converter
#    1472         self.converter = converter
# -> 1473         default = self.converter.default_units(data, self)
#    1474         if default is not None and self.units is None:
#    1475             self.set_units(default)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/category.py in default_units(data, axis)
#     101         # default_units->axis_info->convert
#     102         if axis.units is None:
# --> 103             axis.set_units(UnitData(data))
#     104         else:
#     105             axis.units.update(data)
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/category.py in __init__(self, data)
#     167         self._counter = itertools.count()
#     168         if data is not None:
# --> 169             self.update(data)
#     170
#     171     def update(self, data):
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/category.py in update(self, data)
#     184         data = np.atleast_1d(np.array(data, dtype=object))
#     185
# --> 186         for val in OrderedDict.fromkeys(data):
#     187             if not isinstance(val, (str, bytes)):
#     188                 raise TypeError("{val!r} is not a string".format(val=val))
#
# TypeError: unhashable type: 'numpy.ndarray'
