# %% [markdown]
# Websites that I found data on:
#
# https://blog.nssl.noaa.gov/flash/database/

# %%
import pandas as pd
import numpy as np

# %%
labor = pd.read_csv('./oesm18ma/MSA_M2018_dl.csv')

# %%
labor['PRIM_STATE'].value_counts()
# Out:
# CA    11033
# TX     9452
# FL     8506
# PA     6600
# NC     5559
# OH     5103
# NY     4901
# MI     4625
# GA     4300
# WI     4197
# TN     3942
# IN     3840
# AL     3730
# WA     3704
# VA     3469
# IL     3291
# LA     3220
# MO     3193
# SC     2918
# OR     2895
# CO     2891
# IA     2847
# MA     2834
# CT     2473
# AZ     2469
# MN     2069
# UT     2045
# AR     1944
# WV     1920
# MD     1851
# KY     1820
# OK     1581
# PR     1448
# ID     1418
# NM     1289
# KS     1264
# NV     1251
# NE     1243
# NJ     1217
# MS     1120
# ME      993
# ND      989
# NH      966
# MT      848
# HI      821
# DC      733
# SD      694
# AK      667
# RI      607
# WY      463
# VT      390
# DE      262
# Name: PRIM_STATE, dtype: int64

# %%
dc_stats = labor[labor['PRIM_STATE'] == 'NY'].reset_index()

# %%
dc_stats[dc_stats['OCC_GROUP'] == 'major']
# Out:
#       index PRIM_STATE   AREA                    AREA_NAME OCC_CODE  \
# 1     87577         NY  10580  Albany-Schenectady-Troy, NY  11-0000
# 34    87610         NY  10580  Albany-Schenectady-Troy, NY  13-0000
# 61    87637         NY  10580  Albany-Schenectady-Troy, NY  15-0000
# 78    87654         NY  10580  Albany-Schenectady-Troy, NY  17-0000
# 104   87680         NY  10580  Albany-Schenectady-Troy, NY  19-0000
# 128   87704         NY  10580  Albany-Schenectady-Troy, NY  21-0000
# 144   87720         NY  10580  Albany-Schenectady-Troy, NY  23-0000
# 150   87726         NY  10580  Albany-Schenectady-Troy, NY  25-0000
# 205   87781         NY  10580  Albany-Schenectady-Troy, NY  27-0000
# 233   87809         NY  10580  Albany-Schenectady-Troy, NY  29-0000
# 279   87855         NY  10580  Albany-Schenectady-Troy, NY  31-0000
# 295   87871         NY  10580  Albany-Schenectady-Troy, NY  33-0000
# 314   87890         NY  10580  Albany-Schenectady-Troy, NY  35-0000
# ...
