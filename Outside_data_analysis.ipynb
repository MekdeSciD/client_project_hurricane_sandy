# %%
import pandas as pd
import numpy as np

# %%
labor = pd.read_csv('./oesm18ma/MSA_M2018_dl.csv')

# %%
labor['PRIM_STATE'].value_counts()
# Out:
# CA    11033
# TX     9452
# FL     8506
# PA     6600
# NC     5559
# OH     5103
# NY     4901
# MI     4625
# GA     4300
# WI     4197
# TN     3942
# IN     3840
# AL     3730
# WA     3704
# VA     3469
# IL     3291
# LA     3220
# MO     3193
# SC     2918
# OR     2895
# CO     2891
# IA     2847
# MA     2834
# CT     2473
# AZ     2469
# MN     2069
# UT     2045
# AR     1944
# WV     1920
# MD     1851
# KY     1820
# OK     1581
# PR     1448
# ID     1418
# NM     1289
# KS     1264
# NV     1251
# NE     1243
# NJ     1217
# MS     1120
# ME      993
# ND      989
# NH      966
# MT      848
# HI      821
# DC      733
# SD      694
# AK      667
# RI      607
# WY      463
# VT      390
# DE      262
# Name: PRIM_STATE, dtype: int64

# %%
dc_stats = labor[labor['PRIM_STATE'] == 'DC'].reset_index()

# %%
dc_stats[dc_stats['OCC_GROUP'] == 'detailed']
# Out:
#      index PRIM_STATE   AREA                                     AREA_NAME  \
# 2    25209         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 3    25210         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 4    25211         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 5    25212         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 6    25213         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 7    25214         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 8    25215         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 9    25216         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 10   25217         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 11   25218         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 12   25219         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV
# ...
